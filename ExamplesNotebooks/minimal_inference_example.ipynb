# %% [markdown]
# # One video inference example
#
# This notebook shows how to produce inference values from one mp4 video using utils module functions.

# %% [markdown]
# ## Preparing Input

# %%
from utils import *

# Define the path to the input video
video_path = "example.mp4"
tensor = prepare_input(video_path)
print("Input tensor shape:", tensor.shape)
# Out:
# Input tensor shape: torch.Size([3, 13, 252, 252])

# %% [markdown]
# ## Infering video event type

# %%
# Define the path to the trained model
model_path = "../ExperimentsResults/Checkpoints/exp1/checkpoint.pth"

# Define the path to the labels
labels_path = "../Common/Labels/Exp_1"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

inference_single_video(model_path,tensor,device,labels_path)
